# %% [markdown]
# # Ejercicios

# %% [markdown]
# Los tres dataset que se encuentran la carpeta Dataset contienen:
# * **Cast**
#     * La base de datos de elenco de peliculas, de imdb.
# * **Titles**
#     * La base de datos imdb de titulos de peliculas
# * **Release_dates**
#     * La base de datos imdb de titulos de peliculas y la fecha del estreno en cada país

# %%
import pandas as pd
import numpy as np
import glob
import os

# %%
#cambiar directorio de trabajo a Dataset
os.chdir("./Dataset")

# %%
#lista de todos los archivos csv de la carpeta Dataset
archivos_cast=[i for i in glob.glob('cast_*.csv')]

# %%
archivos_cast
# Out:
# ['cast_part_25.csv',
#  'cast_part_31.csv',
#  'cast_part_28.csv',
#  'cast_part_6.csv',
#  'cast_part_27.csv',
#  'cast_part_8.csv',
#  'cast_part_29.csv',
#  'cast_part_18.csv',
#  'cast_part_35.csv',
#  'cast_part_3.csv',
#  'cast_part_9.csv',
#  'cast_part_24.csv',
#  'cast_part_5.csv',
#  'cast_part_2.csv',
#  'cast_part_32.csv',
#  'cast_part_19.csv',
#  'cast_part_30.csv',
#  'cast_part_22.csv',
#  'cast_part_7.csv',
#  'cast_part_33.csv',
#  'cast_part_4.csv',
#  'cast_part_34.csv',
#  'cast_part_1.csv',
#  'cast_part_36.csv',
#  'cast_part_26.csv',
#  'cast_part_20.csv',
#  'cast_part_23.csv',
#  'cast_part_13.csv',
#  'cast_part_12.csv',
#  'cast_part_14.csv',
#  'cast_part_10.csv',
#  'cast_part_11.csv',
#  'cast_part_15.csv',
#  'cast_part_21.csv',
#  'cast_part_17.csv',
#  'cast_part_16.csv']

# %%
#concatenar todos los archivos cast_part_*.csv en un dataframe
cast=pd.concat([pd.read_csv(f, encoding = "ISO-8859-1",delimiter=";") for f in archivos_cast ])

# %%
cast.to_csv('cast.csv', sep=";")
#pasamos a csv para no tener que leer los csv individuales

# %%
#como ya existe el archivo cast, en vez de rehacerlo entero, se lee
cast=pd.read_csv('cast.csv', encoding = "ISO-8859-1",delimiter=";")

# %%
#ordenado por titulo
cast.sort_values("title", ignore_index=True)
# Out:
#          Unnamed: 0.1  Unnamed: 0             title  year
# 0               22761      322761  #1 Serial Killer  2013  \
# 1               56755     2056755  #1 Serial Killer  2013
# 2               44349     3044349  #1 Serial Killer  2013
# 3               87208      387208  #1 Serial Killer  2013
# 4               94543      394543  #1 Serial Killer  2013
# ...               ...         ...               ...   ...
# 3564645          9607        9607               NaN  2015
# 3564646         38031     1038031               NaN  2015
# 3564647         57093     1457093               NaN  2015
# 3564648         57158     1457158               NaN  2015
# 3564649         59465     1459465               NaN  2015
#
#                          name     type           character     n
# 0              Yvis Cannavale    actor        Homeless Man  25.0
# 1          Eric (II) St. John    actor    Officer Williams   NaN
# 2                   Jinxia Ma  actress     Chinese Teacher  24.0
# 3               Patrick Chien    actor      Cleaver Victim  22.0
# 4             Matthias Chrans    actor       Brian Bennett  13.0
# ...                       ...      ...                 ...   ...
# 3564645           Israel Adam    actor  Landen's Friend #2   NaN
# 3564646          Landen James    actor              Landen   NaN
# 3564647          Elijah Meyer    actor     Landen's Friend   NaN
# 3564648        Emma (V) Meyer    actor  Brock's Girlfriend   NaN
# 3564649  Gabriel (II) Michael    actor          Psychopath   NaN
#
# [3564650 rows x 8 columns]

# %%
titulos=pd.read_csv("./titles.csv", encoding="ISO-8859-1",delimiter=",")
titulos
# Out:
#                                         title  year
# 0                                      Mahler  1974
# 1                Ogon, voda i... mednye truby  1968
# 2       Ana Nojoom bent alasherah wamotalagah  2014
# 3                           Malu de Bicicleta  2010
# 4                  Nazareno Apostol: Boy Ahas  1989
# ...                                       ...   ...
# 230402                          El lobo negro  1981
# 230403                   Komu na Rusi zhit...  1989
# 230404                               Senotaji  2013
# 230405                      The Leopard Woman  1920
# 230406                     Mio caro assassino  1972
#
# [230407 rows x 2 columns]

# %%
estreno=pd.read_csv("./release_dates.csv", encoding="ISO-8859-1",delimiter=",")
estreno
# Out:
#                           title  year      country        date
# 0         #73, Shaanthi Nivaasa  2007        India  2007-06-15
# 1                       #Beings  2015      Romania  2015-01-29
# 2        #Ewankosau saranghaeyo  2015  Philippines  2015-01-21
# 3                       #Horror  2015          USA  2015-11-20
# 4                       #Horror  2015           UK  2016-05-16
# ...                         ...   ...          ...         ...
# 443551  xXx: State of the Union  2005          USA  2005-04-29
# 443552  xXx: State of the Union  2005       Poland  2005-06-03
# 443553  xXx: State of the Union  2005       Turkey  2005-06-03
# 443554  xXx: State of the Union  2005        China  2005-06-17
# 443555  xXx: State of the Union  2005       Greece  2005-06-24
#
# [443556 rows x 4 columns]

# %% [markdown]
# ## Ejercicio 1
# Del fichero **cast.csv** del la carpeta Dataset realice:

# %% [markdown]
# * Peliculas llamadas Dracula

# %%
Dracula=titulos[titulos.title=="Dracula"]
Dracula
# Out:
#           title  year
# 30479   Dracula  1992
# 35229   Dracula  1958
# 62596   Dracula  1999
# 94156   Dracula  1931
# 156968  Dracula  2019
# 184003  Dracula  1979

# %%
Dracula.shape[0]
# Out:
# 6

# %% [markdown]
# * Titulos mas comunes en la historia filmografica.

# %%
#Contar valores de columna de titulos, ordenar de más a menos
comunes=titulos.groupby(["title"])["title"].agg("count").sort_values(ascending=False).head(25)
comunes
# Out:
# title
# Hamlet                  19
# Carmen                  16
# Macbeth                 15
# Maya                    11
# The Outsider            11
# The Three Musketeers    11
# Hero                    11
# Othello                 11
# Anna                    10
# Anna Karenina           10
# Temptation              10
# Kismet                  10
# Vengeance               10
# Paradise                10
# She                     10
# Freedom                 10
# Honeymoon               10
# Borderline               9
# Wanted                   9
# Iris                     9
# Surrender                9
# No Man's Land            9
# Victory                  9
# Avalanche                9
# Underground              9
# Name: title, dtype: int64

# %% [markdown]
# * ¿Cuál fue la primer pelicula hecha titulada ``Romeo and Juliet``

# %%
#de los que coincide el título, ordenar por año y mostrar la primera fila
Romeo_Julieta=cast[["title", "year"]][cast.title=="Romeo and Juliet"].sort_values("year").head(1)
Romeo_Julieta
# Out:
#                     title  year
# 1115232  Romeo and Juliet  1916

# %% [markdown]
# * Listar todas las peliculas que contengan la palabra ``Exorcist`` ordenadas de la más antigua a la más reciente.

# %%
titulo_sin_NaN=titulos.fillna("0")
#rellena con cadena "0" los NaN

# %%
#str.contains daba error al comparar valores NaN.

exorcista=titulo_sin_NaN[titulo_sin_NaN.title.str.contains("Exorcist")].sort_values("year").set_index("title")
exorcista
# Out:
#                                         year
# title
# The Exorcist                            1973
# O Exorcista de Mulheres                 1974
# Exorcist II: The Heretic                1977
# Kung Fu Exorcist                        1978
# The Exorcist III                        1990
# Teenage Exorcist                        1991
# Exorcist: The Beginning                 2004
# Dominion: Prequel to the Exorcist       2005
# Costa Chica: Confession of an Exorcist  2006
# Exorcist Chronicles                     2007
# The Disco Exorcist                      2011
# Exorcist Chronicles                     2013
# Shark Exorcist                          2015
# Bad Exorcists                           2015
# Exorcistas                              2015
# Accidental Exorcist                     2016
# American Exorcist                       2016
# Diary of an Exorcist                    2016
# Exorcist House of Evil                  2016

# %% [markdown]
# * ¿Cuántas peliculas fueron hechas en el año 1950?

# %%
peliculas_1950=titulos[titulos.year==1950].shape[0]
peliculas_1950
# Out:
# 1081

# %% [markdown]
# * ¿Cuántas peliculas fueron hechas en el año 1970?

# %%
peliculas_1970=titulos[titulos.year==1970].shape[0]
peliculas_1970
# Out:
# 2106

# %% [markdown]
# * ¿Cuántas peliculas fueron hechas de 1950 a 1959.

# %%
peliculas_1950_1970=titulos[(titulos.year>=1950)&(titulos.year<=1959)]
peliculas_1950_1970.shape[0]
# Out:
# 12606

# %% [markdown]
# * ¿En qué años alguna pelicula llamada ``Batman`` se estrenó?

# %%
batman=titulos[titulos.title=="Batman"].set_index("title")
batman
# Out:
#         year
# title
# Batman  1989
# Batman  1943

# %% [markdown]
# * ¿Cuántos roles o papeles hubo en la pelicula ``The Godfather``?

# %%
godfather=cast[["name", "type","character"]][cast.title=="The Godfather"].set_index("type").sort_values("name")
godfather
# Out:
#                    name                character
# type
# actor        Abe Vigoda                   Tessio
# actor       Al Lettieri                 Sollozzo
# actor        Al Martino           Johnny Fontane
# actor         Al Pacino         Michael Corleone
# actor        Alex Rocco               Moe Greene
# ...                 ...                      ...
# actor         Tony King        Tony - Stablehand
# actor          Tony Lip            Wedding Guest
# actress   Tybee Brascia  Dancer in Wedding Scene
# actor    Victor Rendina         Philip Tattaglia
# actor       Vito Scotti                 Nazorine
#
# [76 rows x 2 columns]

# %%
godfather.shape[0]
# Out:
# 76

# %% [markdown]
# * ¿Cuántos papeles en la pelicula ``The Godfather`` no estan clasificados en algun valor ``n``?

# %%
# the godfather sin NaN (todos con valor n)
godfather_dropna=cast[cast.title=="The Godfather"].dropna().shape[0]
#todos los actores de Godfather - actores con valor n
godfather.shape[0]-godfather_dropna
# Out:
# 42

# %% [markdown]
# * ¿Cuántos papeles en la pelicula ``The Godfather`` si estuvieron clasificados con un valor ``n``?

# %%
# actores con valor n
godfather_dropna
# Out:
# 34

# %% [markdown]
# * Mostrar el elenco completo de la pelicula ``2001: A Space Odyssey``  ordenado por su clasificasión ``n``, ignorando los papeles que no se les asigno ningun valor ``n``.

# %%
space=cast[["name", "character", "n"]][(cast.title=="2001: A Space Odyssey")].dropna().sort_values("n")
space
# Out:
#                        name                       character     n
# 1802795         Keir Dullea                 Dr. Dave Bowman   1.0
# 2753577       Gary Lockwood                 Dr. Frank Poole   2.0
# 1713186   William Sylvester            Dr. Heywood R. Floyd   3.0
# 1523947      Daniel Richter                    Moon-Watcher   4.0
# 1572093    Leonard Rossiter              Dr. Andrei Smyslov   5.0
# 864754      Margaret Tyzack                           Elena   6.0
# 1351781       Robert Beatty             Dr. Ralph Halvorsen   7.0
# 1701643       Sean Sullivan               Dr. Bill Michaels   8.0
# 775057         Douglas Rain                        HAL 9000   9.0
# 3234560        Frank Miller              Mission Controller  10.0
# 1110523         Bill Weston                       Astronaut  11.0
# 1397975           Ed Bishop  Aries-1B Lunar Shuttle Captain  12.0
# 1353470          Glenn Beck                       Astronaut  13.0
# 588106         Alan Gifford                  Poole's Father  14.0
# 287922           Ann Gillis                  Poole's Mother  15.0
# 2436675      Edwina Carroll             Aries-1B Stewardess  16.0
# 2394229        Penny Brahms                      Stewardess  17.0
# 490543      Heather Downham                      Stewardess  18.0
# 2867633         Mike Lovell                       Astronaut  19.0
# 2285047   John (III) Ashley                             Ape  20.0
# 1361571          Jimmy Bell                             Ape  21.0
# 2073027      David Charkham                             Ape  22.0
# 314378          Simon Davis                             Ape  23.0
# 315635         Jonathan Daw                             Ape  24.0
# 341763         P?ter Delm?r                             Ape  25.0
# 1801760        Terry Duggan         Ape Attacked by Leopard  26.0
# 502077      David Fleetwood                             Ape  27.0
# 1049029        Danny Grover                             Ape  28.0
# 2981575        Brian Hawley                             Ape  29.0
# 3019063         David Hines                             Ape  30.0
# 3095560        Tony Jackson                             Ape  31.0
# 3138883     John (X) Jordan                             Ape  32.0
# 2894606        Scott MacKee                             Ape  33.0
# 2926459   Laurence Marchant                             Ape  34.0
# 3409012         Darryl Paes                             Ape  35.0
# 1501551          Joe Refalo                             Ape  36.0
# 2638337        Andy Wallace                             Ape  37.0
# 1143583         Bob Wilyman                             Ape  38.0
# 1159428  Richard (II) Woods      Ape Killed by Moon-Watcher  39.0

# %% [markdown]
# * Mostrar el elenco completo ordenado por la clasificacion ``n`` de la pelicula ``Dracula`` de 1958

# %%
Dracula_n=cast[(cast.title=="Dracula")&(cast.year==1958)].sort_values("n")
Dracula_n
# Out:
#          Unnamed: 0.1  Unnamed: 0    title  year                   name
# 1285197         85197      485197  Dracula  1958          Peter Cushing  \
# 2706958         42308     1242308  Dracula  1958        Christopher Lee
# 2706957         42307     1242307  Dracula  1958        Christopher Lee
# 1022398         22398      822398  Dracula  1958          Michael Gough
# 810427          10427     3410427  Dracula  1958      Melissa Stribling
# 169196          69196     3069196  Dracula  1958            Carol Marsh
# 477557          77557     2677557  Dracula  1958            Olga Dickie
# 2585636         20986     2220986  Dracula  1958        John Van Eyssen
# 277216          77216     2777216  Dracula  1958          Valerie Gaunt
# 231182          31182     2731182  Dracula  1958            Janina Faye
# 44220           44220     2444220  Dracula  1958         Barbara Archer
# 2750156         85506     1285506  Dracula  1958     Charles Lloyd Pack
# 3218017         53367     1453367  Dracula  1958         George Merritt
# 1157769         57769     2357769  Dracula  1958      George Woodbridge
# 1371732         71732      171732  Dracula  1958          George Benson
# 2912290         47640     1347640  Dracula  1958         Miles Malleson
# 1348496         48496      148496  Dracula  1958       Geoffrey Bayldon
# 1223307         23307      423307  Dracula  1958              Paul Cole
# 3239697         75047     1475047  Dracula  1958              Guy Mills
# 3478084         13434     1513434  Dracula  1958  Richard (VIII) Morgan
# 3489147         24497     1524497  Dracula  1958      John (II) Mossman
#
#             type                 character     n
# 1285197    actor        Doctor Van Helsing   1.0
# 2706958    actor             Count Dracula   2.0
# 2706957    actor                   Dracula   2.0
# 1022398    actor                    Arthur   3.0
# 810427   actress                      Mina   4.0
# 169196   actress                      Lucy   5.0
# 477557   actress                     Gerda   6.0
# 2585636    actor                  Jonathan   7.0
# 277216   actress             Vampire Woman   8.0
# 231182   actress                     Tania   9.0
# 44220    actress                      Inga  10.0
# 2750156    actor             Doctor Seward  11.0
# 3218017    actor                 Policeman  12.0
# 1157769    actor                  Landlord  13.0
# 1371732    actor                  Official  14.0
# 2912290    actor                Undertaker  15.0
# 1348496    actor                    Porter  16.0
# 1223307    actor                       Lad  17.0
# 3239697    actor              Coach Driver   NaN
# 3478084    actor  Coach Driver's Companion   NaN
# 3489147    actor             Hearse Driver   NaN

# %% [markdown]
# * ¿Cuantos papeles fueron listados en la pelicula ``The Wizard of Oz`` de 1939?

# %%
Oz=cast[(cast.title=="The Wizard of Oz")&(cast.year==1939)]
Oz.shape[0]
# Out:
# 128

# %% [markdown]
# * ¿Cuántos papeles de ``Bruce Wayne`` han sido hechos en la historia de las peliculas?

# %%
bruce=cast[cast.character=="Bruce Wayne"]
bruce.shape[0]
# Out:
# 38

# %% [markdown]
# * ¿Cuánta gente ha hecho el papel de ``Romeo``?

# %%
romeo=cast[cast.character=="Romeo"]
romeo.shape[0]
# Out:
# 219

# %% [markdown]
# * ¿Cuántos papeles ha hecho ``Robert De Niro`` en su carrera?

# %%
robert_de_niro=cast[cast.name=="Robert De Niro"]
robert_de_niro.shape[0]
# Out:
# 103

# %% [markdown]
# * Listado de papeles de soporte que tuvo el actor ``Charlton Heston`` en la decada de los 50's, ordenado por año.

# %%
#Todos los papeles de Charlton Heston
charlton_heston=cast[(cast.name=="Charlton Heston")&(cast.year>=1950)&(cast.year<1960)].sort_values("year")
charlton_heston
# Out:
#          Unnamed: 0.1  Unnamed: 0                            title  year
# 3008701         44051      944051                        Dark City  1950  \
# 3008714         44064      944064                    Julius Caesar  1950
# 3008757         44107      944107                       The Savage  1952
# 3008743         44093      944093       The Greatest Show on Earth  1952
# 3008758         44108      944108                       The Savage  1952
# 3008730         44080      944080                      Ruby Gentry  1952
# 3008754         44104      944104             The President's Lady  1953
# 3008695         44045      944045                        Arrowhead  1953
# 3008696         44046      944046               Bad for Each Other  1953
# 3008729         44079      944079                     Pony Express  1953
# 3008748         44098      944098                 The Naked Jungle  1954
# 3008731         44081      944081              Secret of the Incas  1954
# 3008756         44106      944106  The Private War of Major Benson  1955
# 3008717         44067      944067                     Lucy Gallant  1955
# 3008741         44091      944091                 The Far Horizons  1955
# 3008763         44113      944113             Three Violent People  1956
# 3008759         44109      944109             The Ten Commandments  1956
# 3008738         44088      944088                    The Buccaneer  1958
# 3008737         44087      944087                  The Big Country  1958
# 3008765         44115      944115                    Touch of Evil  1958
# 3008697         44047      944047                          Ben-Hur  1959
# 3008762         44112      944112      The Wreck of the Mary Deare  1959
#
#                     name   type                        character    n
# 3008701  Charlton Heston  actor                      Danny Haley  1.0
# 3008714  Charlton Heston  actor                           Antony  2.0
# 3008757  Charlton Heston  actor           James 'Jim' Aherne Jr.  1.0
# 3008743  Charlton Heston  actor                      Brad Braden  3.0
# 3008758  Charlton Heston  actor                       War Bonnet  1.0
# 3008730  Charlton Heston  actor                    Boake Tackman  2.0
# 3008754  Charlton Heston  actor         President Andrew Jackson  2.0
# 3008695  Charlton Heston  actor                        Ed Bannon  1.0
# 3008696  Charlton Heston  actor                     Dr. Tom Owen  1.0
# 3008729  Charlton Heston  actor                Buffalo Bill Cody  1.0
# 3008748  Charlton Heston  actor            Christopher Leiningen  2.0
# 3008731  Charlton Heston  actor                     Harry Steele  1.0
# 3008756  Charlton Heston  actor  Maj. Bernard R. 'Barney' Benson  1.0
# 3008717  Charlton Heston  actor                       Casey Cole  2.0
# 3008741  Charlton Heston  actor                Lt. William Clark  2.0
# 3008763  Charlton Heston  actor              Capt. Colt Saunders  1.0
# 3008759  Charlton Heston  actor                            Moses  1.0
# 3008738  Charlton Heston  actor              Gen. Andrew Jackson  7.0
# 3008737  Charlton Heston  actor                      Steve Leech  4.0
# 3008765  Charlton Heston  actor                      Mike Vargas  1.0
# 3008697  Charlton Heston  actor                    Judah Ben-Hur  1.0
# 3008762  Charlton Heston  actor                       John Sands  2.0

# %%
charlton_heston_secundario=cast[(cast.name=="Charlton Heston")&(cast.year>=1950)&(cast.year<1960)&(cast.n!=1.0)]

# %%
charlton_heston_secundario.reset_index()
# Out:
#      index  Unnamed: 0.1  Unnamed: 0                        title  year
# 0  3008714         44064      944064                Julius Caesar  1950  \
# 1  3008717         44067      944067                 Lucy Gallant  1955
# 2  3008730         44080      944080                  Ruby Gentry  1952
# 3  3008737         44087      944087              The Big Country  1958
# 4  3008738         44088      944088                The Buccaneer  1958
# 5  3008741         44091      944091             The Far Horizons  1955
# 6  3008743         44093      944093   The Greatest Show on Earth  1952
# 7  3008748         44098      944098             The Naked Jungle  1954
# 8  3008754         44104      944104         The President's Lady  1953
# 9  3008762         44112      944112  The Wreck of the Mary Deare  1959
#
#               name   type                 character    n
# 0  Charlton Heston  actor                    Antony  2.0
# 1  Charlton Heston  actor                Casey Cole  2.0
# 2  Charlton Heston  actor             Boake Tackman  2.0
# 3  Charlton Heston  actor               Steve Leech  4.0
# 4  Charlton Heston  actor       Gen. Andrew Jackson  7.0
# 5  Charlton Heston  actor         Lt. William Clark  2.0
# 6  Charlton Heston  actor               Brad Braden  3.0
# 7  Charlton Heston  actor     Christopher Leiningen  2.0
# 8  Charlton Heston  actor  President Andrew Jackson  2.0
# 9  Charlton Heston  actor                John Sands  2.0

# %% [markdown]
# * Listado de papeles como protagonista que tuvo el actor ``Charlton Heston`` en la decada de los 60's, ordenado por año de forma descendente.

# %%
#Todos los principales
charlton_heston_principal=cast[(cast.name=="Charlton Heston")&(cast.year>=1950)&(cast.year<1960)&(cast.n==1.0)].sort_values("year", ascending=False).reset_index()
charlton_heston_principal
# Out:
#       index  Unnamed: 0.1  Unnamed: 0                            title  year
# 0   3008697         44047      944047                          Ben-Hur  1959  \
# 1   3008765         44115      944115                    Touch of Evil  1958
# 2   3008759         44109      944109             The Ten Commandments  1956
# 3   3008763         44113      944113             Three Violent People  1956
# 4   3008756         44106      944106  The Private War of Major Benson  1955
# 5   3008731         44081      944081              Secret of the Incas  1954
# 6   3008695         44045      944045                        Arrowhead  1953
# 7   3008696         44046      944046               Bad for Each Other  1953
# 8   3008729         44079      944079                     Pony Express  1953
# 9   3008757         44107      944107                       The Savage  1952
# 10  3008758         44108      944108                       The Savage  1952
# 11  3008701         44051      944051                        Dark City  1950
#
#                name   type                        character    n
# 0   Charlton Heston  actor                    Judah Ben-Hur  1.0
# 1   Charlton Heston  actor                      Mike Vargas  1.0
# 2   Charlton Heston  actor                            Moses  1.0
# 3   Charlton Heston  actor              Capt. Colt Saunders  1.0
# 4   Charlton Heston  actor  Maj. Bernard R. 'Barney' Benson  1.0
# 5   Charlton Heston  actor                     Harry Steele  1.0
# 6   Charlton Heston  actor                        Ed Bannon  1.0
# 7   Charlton Heston  actor                     Dr. Tom Owen  1.0
# 8   Charlton Heston  actor                Buffalo Bill Cody  1.0
# 9   Charlton Heston  actor           James 'Jim' Aherne Jr.  1.0
# 10  Charlton Heston  actor                       War Bonnet  1.0
# 11  Charlton Heston  actor                      Danny Haley  1.0

# %% [markdown]
# * ¿Cuántos papeles para actores hubo en la decada de los 50's?

# %%
actores_50s=cast[(cast.type=="actor")&(cast.year>=1950)&(cast.year<1960)]
actores_50s.shape[0]
# Out:
# 153998

# %% [markdown]
# * ¿Cuántos papeles para actrices hubo en la decada de los 50's ?

# %%
actrices_50s=cast[(cast.type=="actress")&(cast.year>=1950)&(cast.year<1960)]
actrices_50s.shape[0]
# Out:
# 56004

# %% [markdown]
# * ¿Cuantos papeles protagonistas existen desde el principio de la historia filmatografica hasta 1970 ?

# %%
papeles_1970=cast[(cast.year<1970)&(cast.n==1)]
papeles_1970.shape[0]
# Out:
# 50189

# %% [markdown]
# ## Ejercicio 2

# %% [markdown]
# * Graficar la diferencia entre el numero de papeles  para actores cada año y el numero de papeles para actrices cada año en la historia de la filmografia.

# %%
actores_por_año=cast[(cast.type=="actor")].groupby("year")["type"].count().sort_values(ascending=False)
actores_por_año
# Out:
# year
# 2016    112298
# 2015     95253
# 2014     94263
# 2013     90025
# 2012     86109
#          ...
# 1909         3
# 1894         2
# 1900         2
# 1905         1
# 2023         1
# Name: type, Length: 121, dtype: int64

# %%
actrices_por_año=cast[(cast.type=="actress")].groupby("year")["type"].count().sort_values(ascending=False)
actrices_por_año
# Out:
# year
# 2016    66497
# 2015    54651
# 2014    53136
# 2013    48359
# 2012    46481
#         ...
# 1908       13
# 2022        7
# 2021        6
# 1906        3
# 1894        1
# Name: type, Length: 116, dtype: int64

# %%
import matplotlib.pyplot as plt
plot_actores=plt.plot(actores_por_año)
plot_actores=plt.plot(actrices_por_año)

# %% [markdown]
# * El mismo grafico anterior pero categorizado por decada y con un grafico de area.
# * Graficar el porcentaje de papeles que han sido actores cada año en la historia de la filmografia
# * Graficar el porcentaje de papeles que han sido  actores cada año en la historia de la filmografia junto al mismo porcentaje pero de actrices
# * Graficar 3 lines con clasificacion "n" de 1 al 3 donde cada  linea represente el porcentaje de la clasificacion para  los papeles de actores en cada año.
# * Encontrar las 5 peliculas de la historia tengan más actrices que actores

# %% [markdown]
# ## Ejercicio 3

# %% [markdown]
# * En que fechas fue lanzada cada pelicula de ``Salma Hayek`` desde  1990 al presente en Mexico

# %%
peliculas_mexicanas=estreno[["title", "date"]][(estreno.country=="Mexico")&(estreno.year>=1990)]
peliculas_mexicanas

salma=cast[cast.name=="Salma Hayek"]

salma.reset_index(drop=True)
#  merge peliculas_mexicanas y salma
# Out:
#     Unnamed: 0.1  Unnamed: 0                                          title
# 0          47362     2847362                                             54  \
# 1          47363     2847363                            Across the Universe
# 2          47364     2847364                               After the Sunset
# 3          47365     2847365                                      Americano
# 4          47366     2847366                                   Ask the Dust
# 5          47367     2847367                                       Bandidas
# 6          47368     2847368                              Beatriz at Dinner
# 7          47369     2847369                                    Breaking Up
# 8          47370     2847370                                 Chain of Fools
# 9          47371     2847371       Cirque du Freak: The Vampire's Assistant
# 10         47372     2847372                                      Desperado
# 11         47373     2847373                                          Dogma
# 12         47374     2847374           El coronel no tiene quien le escriba
# 13         47375     2847375                                         Everly
# 14         47376     2847376                                      Fair Game
# 15         47377     2847377                                           Fled
# 16         47378     2847378                                 Follow Me Home
# 17         47379     2847379                                  Fools Rush In
# 18         47380     2847380                                     Four Rooms
# 19         47381     2847381                                          Frida
# 20         47382     2847382                            From Dusk Till Dawn
# 21         47383     2847383                                      Grown Ups
# 22         47384     2847384                                    Grown Ups 2
# 23         47385     2847385                            Here Comes the Boom
# 24         47386     2847386                                          Hotel
# 25         47387     2847387            How to Make Love Like an Englishman
# 26         47388     2847388       Il racconto dei racconti - Tale of Tales
# 27         47389     2847389                           La chispa de la vida
# 28         47390     2847390                                   La gran vida
# 29         47391     2847391                                  Lonely Hearts
# 30         47392     2847392                                   Mi vida loca
# 31         47393     2847393                            Muppets Most Wanted
# 32         47394     2847394                     Once Upon a Time in Mexico
# 33         47395     2847395                                  Puss in Boots
# 34         47396     2847396                                  Sausage Party
# 35         47397     2847397                                        Savages
# 36         47398     2847398                           Septembers of Shiraz
# 37         47399     2847399                        Spy Kids 3-D: Game Over
# 38         47400     2847400                                    The Faculty
# 39         47401     2847401  The Pirates! In an Adventure with Scientists!
# 40         47402     2847402                                    The Prophet
# 41         47403     2847403     The Velocity of Gary* *(Not His Real Name)
# 42         47404     2847404                                       Timecode
# 43         47405     2847405                                        Traffic
# 44         47406     2847406                           Welcome to Hollywood
# 45         47407     2847407                                 Wild Wild West
#
#     year         name     type                                    character
# 0   1998  Salma Hayek  actress                               Anita Randazzo  \
# 1   2007  Salma Hayek  actress                                Singing Nurse
# 2   2004  Salma Hayek  actress                                 Lola Cirillo
# 3   2011  Salma Hayek  actress                                       'Lola'
# 4   2006  Salma Hayek  actress                                      Camilla
# 5   2006  Salma Hayek  actress                                Sara Sandoval
# 6   2017  Salma Hayek  actress                                      Beatriz
# 7   1997  Salma Hayek  actress                                       Monica
# 8   2000  Salma Hayek  actress                                        Kolko
# 9   2009  Salma Hayek  actress                                Madame Truska
# 10  1995  Salma Hayek  actress                                     Carolina
# 11  1999  Salma Hayek  actress                                  Serendipity
# 12  1999  Salma Hayek  actress                                        Julia
# 13  2014  Salma Hayek  actress                                       Everly
# 14  1995  Salma Hayek  actress                                         Rita
# 15  1996  Salma Hayek  actress                                         Cora
# 16  1996  Salma Hayek  actress                                     Veronica
# 17  1997  Salma Hayek  actress                       Isabel Fuentes Whitman
# 18  1995  Salma Hayek  actress  TV Dancing Girl (segment "The Misbehavers")
# 19  2002  Salma Hayek  actress                                  Frida Kahlo
# 20  1996  Salma Hayek  actress                        Santanico Pandemonium
# 21  2010  Salma Hayek  actress                          Roxanne Chase-Feder
# 22  2013  Salma Hayek  actress                          Roxanne Chase-Feder
# 23  2012  Salma Hayek  actress                                 Bella Flores
# 24  2001  Salma Hayek  actress                                 Charlee Boux
# 25  2014  Salma Hayek  actress                                       Olivia
# 26  2015  Salma Hayek  actress                         Queen of Longtrellis
# 27  2011  Salma Hayek  actress                                        Luisa
# 28  2000  Salma Hayek  actress                                         Lola
# 29  2006  Salma Hayek  actress                                  Martha Beck
# 30  1993  Salma Hayek  actress                                         Gata
# 31  2014  Salma Hayek  actress                                      Herself
# 32  2003  Salma Hayek  actress                                     Carolina
# 33  2011  Salma Hayek  actress                               Kitty Softpaws
# 34  2016  Salma Hayek  actress                                       Teresa
# 35  2012  Salma Hayek  actress                                        Elena
# 36  2015  Salma Hayek  actress                                       Farnez
# 37  2003  Salma Hayek  actress                                Cesca Giggles
# 38  1998  Salma Hayek  actress                            Nurse Rosa Harper
# 39  2012  Salma Hayek  actress                                  Cutlass Liz
# 40  2014  Salma Hayek  actress                                       Kamila
# 41  1998  Salma Hayek  actress                                  Mary Carmen
# 42  2000  Salma Hayek  actress                                         Rose
# 43  2000  Salma Hayek  actress                                      Rosario
# 44  1998  Salma Hayek  actress                                      Herself
# 45  1999  Salma Hayek  actress                                 Rita Escobar
#
#        n
# 0    2.0
# 1   66.0
# 2    2.0
# 3    6.0
# 4    2.0
# 5    2.0
# 6    NaN
# 7    2.0
# 8    2.0
# 9   12.0
# 10   2.0
# 11  28.0
# 12   3.0
# 13   1.0
# 14   7.0
# 15  11.0
# 16   2.0
# 17   2.0
# 18  15.0
# 19   1.0
# 20   6.0
# 21   6.0
# 22   5.0
# 23   2.0
# 24  13.0
# 25   2.0
# 26   1.0
# 27   2.0
# 28   1.0
# 29   4.0
# 30  24.0
# 31  24.0
# 32   2.0
# 33   2.0
# 34  12.0
# 35  17.0
# 36   NaN
# 37   9.0
# 38   6.0
# 39   6.0
# 40   NaN
# 41   2.0
# 42   7.0
# 43   NaN
# 44   NaN
# 45   4.0

# %%
salma_mexico=pd.merge(peliculas_mexicanas,salma, left_on="title", right_on="title", how="inner")[["title","date"]].set_index("title")

# %%
salma_mexico.sort_values("date")
# Out:
#                                                      date
# title
# From Dusk Till Dawn                            1996-06-14
# Four Rooms                                     1996-11-13
# Fools Rush In                                  1997-05-16
# El coronel no tiene quien le escriba           1999-09-16
# Traffic                                        2001-03-19
# La gran vida                                   2001-06-01
# Frida                                          2002-11-20
# Spy Kids 3-D: Game Over                        2003-10-10
# Once Upon a Time in Mexico                     2003-10-24
# After the Sunset                               2005-01-14
# Bandidas                                       2006-02-17
# Ask the Dust                                   2006-11-17
# Lonely Hearts                                  2007-07-20
# Across the Universe                            2007-11-16
# Hotel                                          2008-05-29
# Cirque du Freak: The Vampire's Assistant       2009-10-30
# Grown Ups                                      2010-07-23
# Fair Game                                      2011-03-25
# Puss in Boots                                  2011-10-28
# The Pirates! In an Adventure with Scientists!  2012-04-20
# Savages                                        2012-07-13
# La chispa de la vida                           2012-11-02
# Americano                                      2012-12-07
# Here Comes the Boom                            2012-12-28
# Grown Ups 2                                    2013-08-16
# How to Make Love Like an Englishman            2015-09-03
# The Prophet                                    2016-01-22
# Sausage Party                                  2016-10-30

# %% [markdown]
# * En que dia de la semana se han lanzado en USA las peliculas donde aparece ``Tom Cruise``. Incluir un grafico

# %%
cast
# Out:
#          Unnamed: 0.1  Unnamed: 0                    title  year
# 0                   0     2400000       Where Y'At (Hello)  2012  \
# 1                   1     2400001                Funny Man  2016
# 2                   2     2400002           The Dark Tapes  2017
# 3                   3     2400003         Dead Men Walking  2005
# 4                   4     2400004         Straight Shooter  1999
# ...               ...         ...                      ...   ...
# 3564645         99995     1599995              Himlaspelet  1942
# 3564646         99996     1599996                Jerusalem  1996
# 3564647         99997     1599997       Kan doktorn komma?  1942
# 3564648         99998     1599998                  Katrina  1943
# 3564649         99999     1599999  Kejsarn av Portugallien  1944
#
#                            name   type                       character     n
# 0                  Tony Ziegler  actor                            Dude   NaN
# 1        Zachariah Axel Ziegler  actor               Bluejacket Member   NaN
# 2        Zachariah Axel Ziegler  actor                      Party Goer   NaN
# 3           Steven Zieglermeyer  actor                            Andy  23.0
# 4          Martin M. Zieglmeier  actor                      Henkelmann  30.0
# ...                         ...    ...                             ...   ...
# 3564645          Anders Nystr?m  actor                        Shepherd   NaN
# 3564646          Anders Nystr?m  actor                    Sven Persson  24.0
# 3564647          Anders Nystr?m  actor             Boy with tooth ache   NaN
# 3564648          Anders Nystr?m  actor  Herman, Saga's and Einar's son   NaN
# 3564649          Anders Nystr?m  actor                  August aged 12   NaN
#
# [3564650 rows x 8 columns]

# %%
from datetime import datetime

peliculas_USA=estreno[estreno.country=="USA"]
tom_cruise=cast[cast.name=="Tom Cruise"]

# %%
#merge peliculas USA con estrenos de tom cruise por título
tom_USA=pd.merge(peliculas_USA, tom_cruise, left_on="title", right_on="title", how="inner")[["title", "date"]].set_index("title")

tom_USA["fecha"]=pd.to_datetime(tom_USA["date"])
#crear columna "dia", a partir de la columna "date"

# %%
tom_USA.drop(columns=["date"], inplace=True)

# %%
diasSemana=["Lunes","Martes","Miércoles","Jueves","Viernes","Sábado","Domingo"]

# %%
tom_USA.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 54 entries, A Few Good Men to War of the Worlds
# Data columns (total 1 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   fecha   54 non-null     datetime64[ns]
# dtypes: datetime64[ns](1)
# memory usage: 864.0+ bytes

# %%
tom_USA["diasemana"]=tom_USA["fecha"].dt.day_name()
tom_USA.sort_values("fecha")
# Out:
#                                                         fecha  diasemana
# title
# Risky Business                                     1926-10-04     Monday
# The Mummy                                          1932-12-22   Thursday
# Risky Business                                     1939-03-03     Friday
# The Mummy                                          1959-12-16  Wednesday
# Endless Love                                       1981-07-17     Friday
# Taps                                               1981-12-25     Friday
# The Outsiders                                      1983-03-25     Friday
# Losin' It                                          1983-04-22     Friday
# Risky Business                                     1983-08-05     Friday
# All the Right Moves                                1983-10-21     Friday
# Legend                                             1986-04-18     Friday
# Top Gun                                            1986-05-16     Friday
# The Color of Money                                 1986-10-17     Friday
# Cocktail                                           1988-07-29     Friday
# Rain Man                                           1988-12-16     Friday
# Born on the Fourth of July                         1990-01-05     Friday
# Days of Thunder                                    1990-06-27  Wednesday
# Far and Away                                       1992-05-22     Friday
# A Few Good Men                                     1992-12-11     Friday
# The Firm                                           1993-06-30  Wednesday
# Interview with the Vampire: The Vampire Chronicles 1994-11-11     Friday
# August                                             1996-04-19     Friday
# Mission: Impossible                                1996-05-22  Wednesday
# Jerry Maguire                                      1996-12-13     Friday
# The Last Samurai                                   1997-02-28     Friday
# The Mummy                                          1999-05-07     Friday
# Eyes Wide Shut                                     1999-07-16     Friday
# Magnolia                                           2000-01-07     Friday
# Mission: Impossible II                             2000-05-24  Wednesday
# Vanilla Sky                                        2001-12-14     Friday
# Minority Report                                    2002-06-21     Friday
# Austin Powers in Goldmember                        2002-07-26     Friday
# Austin Powers in Goldmember                        2002-07-26     Friday
# The Last Samurai                                   2003-12-05     Friday
# Collateral                                         2004-08-06     Friday
# War of the Worlds                                  2005-06-29  Wednesday
# Mission: Impossible III                            2006-05-05     Friday
# The Queen                                          2006-11-17     Friday
# Lions for Lambs                                    2007-11-09     Friday
# Tropic Thunder                                     2008-08-13  Wednesday
# Valkyrie                                           2008-12-25   Thursday
# Knight and Day                                     2010-06-23  Wednesday
# Mission: Impossible - Ghost Protocol               2011-12-21  Wednesday
# Rock of Ages                                       2012-06-15     Friday
# Jack Reacher                                       2012-12-21     Friday
# Oblivion                                           2013-04-19     Friday
# Endless Love                                       2014-02-14     Friday
# Edge of Tomorrow                                   2014-06-06     Friday
# Mission: Impossible - Rogue Nation                 2015-07-31     Friday
# Legend                                             2015-11-20     Friday
# The Big Short                                      2015-12-23  Wednesday
# Jack Reacher: Never Go Back                        2016-10-21     Friday
# The Mummy                                          2017-06-09     Friday
# American Made                                      2017-09-29     Friday

# %%
plt.plot(tom_USA["title"], tom_USA["diasemana"])
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File ~/.local/lib/python3.10/site-packages/pandas/core/indexes/base.py:3652, in Index.get_loc(self, key)
#    3651 try:
# -> 3652     return self._engine.get_loc(casted_key)
#    3653 except KeyError as err:
#
# File ~/.local/lib/python3.10/site-packages/pandas/_libs/index.pyx:147, in pandas._libs.index.IndexEngine.get_loc()
#
# File ~/.local/lib/python3.10/site-packages/pandas/_libs/index.pyx:176, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas/_libs/hashtable_class_helper.pxi:7080, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas/_libs/hashtable_class_helper.pxi:7088, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'title'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Cell In[46], line 1
# ----> 1 plt.plot(tom_USA["title"], tom_USA["diasemana"])
#
# File ~/.local/lib/python3.10/site-packages/pandas/core/frame.py:3761, in DataFrame.__getitem__(self, key)
#    3759 if self.columns.nlevels > 1:
#    3760     return self._getitem_multilevel(key)
# -> 3761 indexer = self.columns.get_loc(key)
#    3762 if is_integer(indexer):
#    3763     indexer = [indexer]
#
# File ~/.local/lib/python3.10/site-packages/pandas/core/indexes/base.py:3654, in Index.get_loc(self, key)
#    3652     return self._engine.get_loc(casted_key)
#    3653 except KeyError as err:
# -> 3654     raise KeyError(key) from err
#    3655 except TypeError:
#    3656     # If we have a listlike key, _check_indexing_error will raise
#    3657     #  InvalidIndexError. Otherwise we fall through and re-raise
#    3658     #  the TypeError.
#    3659     self._check_indexing_error(key)
#
# KeyError: 'title'

# %% [markdown]
# * ¿Que peliculas han sido lanzadas en la mayor cantidad de paises?, incluir en un grafico las 5 mayores.

# %%
estreno[["title","country"]].sort_values("title")
# Out:
#                           title               country
# 0         #73, Shaanthi Nivaasa                 India
# 1                       #Beings               Romania
# 2        #Ewankosau saranghaeyo           Philippines
# 3                       #Horror                   USA
# 4                       #Horror                    UK
# ...                         ...                   ...
# 443530  xXx: State of the Union             Hong Kong
# 443531  xXx: State of the Union               Hungary
# 443523  xXx: State of the Union  United Arab Emirates
# 443555  xXx: State of the Union                Greece
# 245852                      NaN                   USA
#
# [443556 rows x 2 columns]

# %%
nº_paises=estreno.groupby("country").ngroups 
nº_paises #189 paises distintos
# Out:
# 189

# %%
peliculas_por_pais=estreno[["country","title"]].groupby("country").count().sort_values(by="title",ascending=False)
#nº de peliculas estrenadas en cada pais
peliculas_por_pais.head(15)
# Out:
#               title
# country
# USA           43811
# France        23956
# Finland       18829
# Portugal      18623
# Denmark       17850
# Sweden        17575
# Japan         16950
# UK            15558
# Italy         13103
# Mexico        12470
# India         11883
# West Germany  11316
# Spain         10393
# Netherlands   10389
# Australia     10196

# %%
estrenos_x_paises=estreno[["title", "country"]].groupby("title")
estrenos_x_paises.count().sort_values(by="country", ascending=False).head(15)
# Out:
#                               country
# title
# Fantastic Four                    136
# The Three Musketeers              125
# Hercules                          120
# The Avengers                      120
# Godzilla                          117
# Carrie                            109
# Anna Karenina                     109
# Alice in Wonderland               107
# RoboCop                           107
# The Jungle Book                   104
# Teenage Mutant Ninja Turtles      103
# Poltergeist                       100
# King Kong                          99
# Annie                              97
# Fury                               95

# %% [markdown]
# * ¿Quien tiende a ser el actor si clasificado (n > 1) que mas ha participado en peliculas donde el protagonista es ``Leonardo DiCaprio``?

# %%
cast.head(5)
# Out:
#    Unnamed: 0.1  Unnamed: 0               title  year                    name
# 0             0     2400000  Where Y'At (Hello)  2012            Tony Ziegler  \
# 1             1     2400001           Funny Man  2016  Zachariah Axel Ziegler
# 2             2     2400002      The Dark Tapes  2017  Zachariah Axel Ziegler
# 3             3     2400003    Dead Men Walking  2005     Steven Zieglermeyer
# 4             4     2400004    Straight Shooter  1999    Martin M. Zieglmeier
#
#     type          character     n
# 0  actor               Dude   NaN
# 1  actor  Bluejacket Member   NaN
# 2  actor         Party Goer   NaN
# 3  actor               Andy  23.0
# 4  actor         Henkelmann  30.0

# %%
cast[cast.name=="Leonardo DiCaprio"].head(2)
# Out:
#         Unnamed: 0.1  Unnamed: 0          title  year               name
# 362258         62258      562258  Blood Diamond  2006  Leonardo DiCaprio  \
# 362259         62259      562259   Body of Lies  2008  Leonardo DiCaprio
#
#          type     character    n
# 362258  actor  Danny Archer  1.0
# 362259  actor  Roger Ferris  1.0

# %%
estreno.head(2)
# Out:
#                    title  year  country        date
# 0  #73, Shaanthi Nivaasa  2007    India  2007-06-15
# 1                #Beings  2015  Romania  2015-01-29

# %%
titulos.head(2)
# Out:
#                           title  year
# 0                        Mahler  1974
# 1  Ogon, voda i... mednye truby  1968

# %%
#peliculas con Leonardo como protagonista
leonardo=cast['title'][(cast.name=="Leonardo DiCaprio")&(cast.n==1)]

#lista de actores list de peliculas de Leonardo
