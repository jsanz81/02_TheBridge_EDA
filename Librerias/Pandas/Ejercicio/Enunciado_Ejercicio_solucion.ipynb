# %% [markdown]
# # Ejercicios

# %% [markdown]
# Los tres dataset que se encuentran la carpeta Dataset contienen:
# * **Cast**
#     * La base de datos de elenco de peliculas, de imdb.
# * **Titles**
#     * La base de datos imdb de titulos de peliculas
# * **Release_dates**
#     * La base de datos imdb de titulos de peliculas y la fecha del estreno en cada país

# %%
import pandas as pd
import numpy as np
import glob
import os
# Out:
# No se pudo conectar con el servidor de Jupyter remoto.
#
# Compruebe que se pueda obtener acceso a la dirección URL del servidor de Jupyter desde un explorador.
#
# https://jsanz81-jupyter-server-vxg46v644grh6wpq-8888.preview.app.github.dev/. Haga clic <a href='https://aka.ms/vscjremoteweb'>aquí</a> para obtener más información.

# %%
#cambiar directorio de trabajo a Dataset
os.chdir("./Dataset")

# %%
#lista de todos los archivos csv de la carpeta Dataset
archivos_cast=[i for i in glob.glob('cast_*.csv')]

# %%
archivos_cast
# Out:
# ['cast_part_1.csv',
#  'cast_part_10.csv',
#  'cast_part_11.csv',
#  'cast_part_12.csv',
#  'cast_part_13.csv',
#  'cast_part_14.csv',
#  'cast_part_15.csv',
#  'cast_part_16.csv',
#  'cast_part_17.csv',
#  'cast_part_18.csv',
#  'cast_part_19.csv',
#  'cast_part_2.csv',
#  'cast_part_20.csv',
#  'cast_part_21.csv',
#  'cast_part_22.csv',
#  'cast_part_23.csv',
#  'cast_part_24.csv',
#  'cast_part_25.csv',
#  'cast_part_26.csv',
#  'cast_part_27.csv',
#  'cast_part_28.csv',
#  'cast_part_29.csv',
#  'cast_part_3.csv',
#  'cast_part_30.csv',
#  'cast_part_31.csv',
#  'cast_part_32.csv',
#  'cast_part_33.csv',
#  'cast_part_34.csv',
#  'cast_part_35.csv',
#  'cast_part_36.csv',
#  'cast_part_4.csv',
#  'cast_part_5.csv',
#  'cast_part_6.csv',
#  'cast_part_7.csv',
#  'cast_part_8.csv',
#  'cast_part_9.csv']

# %%
#concatenar todos los archivos cast_part_*.csv en un dataframe
cast=pd.concat([pd.read_csv(f, encoding = "ISO-8859-1",delimiter=";") for f in archivos_cast ])

# %%
cast.to_csv('cast.csv', sep=";")
#pasamos a csv para no tener que leer los csv individuales

# %%
cast
# Out:
#        Unnamed: 0                   title  year             name   type
# 0               0          Closet Monster  2015         Buffy #1  actor  \
# 1               1         Suuri illusioni  1985           Homo $  actor
# 2               2     Battle of the Sexes  2017          $hutter  actor
# 3               3    Secret in Their Eyes  2015          $hutter  actor
# 4               4              Steve Jobs  2015          $hutter  actor
# ...           ...                     ...   ...              ...    ...
# 99995      899995                 Nanking  2007  Woody Harrelson  actor
# 99996      899996    Natural Born Killers  1994  Woody Harrelson  actor
# 99997      899997  No Country for Old Men  2007  Woody Harrelson  actor
# 99998      899998           North Country  2005  Woody Harrelson  actor
# 99999      899999          Now You See Me  2013  Woody Harrelson  actor
#
#                      character     n
# 0                      Buffy 4  31.0
# 1                       Guests  22.0
# 2              Bobby Riggs Fan  10.0
# 3              2002 Dodger Fan   NaN
# 4      1988 Opera House Patron   NaN
# ...                        ...   ...
# 99995               Bob Wilson  13.0
# 99996              Mickey Knox   2.0
# 99997             Carson Wells   4.0
# 99998               Bill White   6.0
# 99999         Merritt McKinney   3.0
#
# [3564650 rows x 7 columns]

# %%
#ordenado por titulo
cast.sort_values("title", ignore_index=True)
# Out:
#          Unnamed: 0             title  year                  name     type
# 0           2120507  #1 Serial Killer  2013       Brian Takahashi    actor  \
# 1           1039200  #1 Serial Killer  2013          Rane Jameson    actor
# 2            400738  #1 Serial Killer  2013       Robert Cicchini    actor
# 3           1514850  #1 Serial Killer  2013  Thomas Isao Morinaka    actor
# 4           2559396  #1 Serial Killer  2013        Kasie Callaway  actress
# ...             ...               ...   ...                   ...      ...
# 3564645     1038031               NaN  2015          Landen James    actor
# 3564646     1457093               NaN  2015          Elijah Meyer    actor
# 3564647     1457158               NaN  2015        Emma (V) Meyer    actor
# 3564648     1459465               NaN  2015  Gabriel (II) Michael    actor
# 3564649      251768               NaN  2015          Brock Brazda    actor
#
#                   character     n
# 0           Stabbing Victim  20.0
# 1          Micah Betancourt   6.0
# 2        Detective Phillips   9.0
# 3              Policeman #1  19.0
# 4                Cathherine  16.0
# ...                     ...   ...
# 3564645              Landen   NaN
# 3564646     Landen's Friend   NaN
# 3564647  Brock's Girlfriend   NaN
# 3564648          Psychopath   NaN
# 3564649               Brock   NaN
#
# [3564650 rows x 7 columns]

# %%
titulos=pd.read_csv("./titles.csv", encoding="ISO-8859-1",delimiter=",")
titulos
# Out:
#                                         title  year
# 0                                      Mahler  1974
# 1                Ogon, voda i... mednye truby  1968
# 2       Ana Nojoom bent alasherah wamotalagah  2014
# 3                           Malu de Bicicleta  2010
# 4                  Nazareno Apostol: Boy Ahas  1989
# ...                                       ...   ...
# 230402                          El lobo negro  1981
# 230403                   Komu na Rusi zhit...  1989
# 230404                               Senotaji  2013
# 230405                      The Leopard Woman  1920
# 230406                     Mio caro assassino  1972
#
# [230407 rows x 2 columns]

# %%
estreno=pd.read_csv("./release_dates.csv", encoding="ISO-8859-1",delimiter=",")
estreno
# Out:
#                           title  year      country        date
# 0         #73, Shaanthi Nivaasa  2007        India  2007-06-15
# 1                       #Beings  2015      Romania  2015-01-29
# 2        #Ewankosau saranghaeyo  2015  Philippines  2015-01-21
# 3                       #Horror  2015          USA  2015-11-20
# 4                       #Horror  2015           UK  2016-05-16
# ...                         ...   ...          ...         ...
# 443551  xXx: State of the Union  2005          USA  2005-04-29
# 443552  xXx: State of the Union  2005       Poland  2005-06-03
# 443553  xXx: State of the Union  2005       Turkey  2005-06-03
# 443554  xXx: State of the Union  2005        China  2005-06-17
# 443555  xXx: State of the Union  2005       Greece  2005-06-24
#
# [443556 rows x 4 columns]

# %% [markdown]
# ## Ejercicio 1
# Del fichero **cast.csv** del la carpeta Dataset realice:

# %% [markdown]
# * Peliculas llamadas Dracula

# %%
Dracula=titulos[titulos.title=="Dracula"]
Dracula
# Out:
#           title  year
# 30479   Dracula  1992
# 35229   Dracula  1958
# 62596   Dracula  1999
# 94156   Dracula  1931
# 156968  Dracula  2019
# 184003  Dracula  1979

# %%
Dracula.shape[0]
# Out:
# 6

# %% [markdown]
# * Titulos mas comunes en la historia filmografica.

# %%
#contar valores de fila titulo, ordenar de más a menos, mostrar los 15 primeros
comunes=cast.groupby(["title"])["title"].agg("count").sort_values(ascending=False).head(15)
comunes
# Out:
# title
# Around the World in Eighty Days       1299
# 7 cajas                                689
# Thelma                                 580
# The Ten Commandments                   532
# The Eschatrilogy: Book of the Dead     517
# Catching Faith                         493
# The Dark Knight Rises                  450
# Welcome to Essex                       448
# Stuck on You                           437
# The Buccaneer                          436
# The Producers                          425
# King Kong                              410
# Dekada '70                             409
# Diary ng panget                        401
# Across the Universe                    386
# Name: title, dtype: int64

# %%
#de titulos
comunes=titulos.groupby(["title"])["title"].agg("count").sort_values(ascending=False).head(25)
comunes
# Out:
# title
# Hamlet                  19
# Carmen                  16
# Macbeth                 15
# Maya                    11
# The Outsider            11
# The Three Musketeers    11
# Hero                    11
# Othello                 11
# Anna                    10
# Anna Karenina           10
# Temptation              10
# Kismet                  10
# Vengeance               10
# Paradise                10
# She                     10
# Freedom                 10
# Honeymoon               10
# Borderline               9
# Wanted                   9
# Iris                     9
# Surrender                9
# No Man's Land            9
# Victory                  9
# Avalanche                9
# Underground              9
# Name: title, dtype: int64

# %% [markdown]
# * ¿Cuál fue la primer pelicula hecha titulada ``Romeo and Juliet``

# %%
#de los que coincide el título, ordenar por año y mostrar la primera fila
Romeo_Julieta=cast[["title", "year"]][cast.title=="Romeo and Juliet"].sort_values("year").head(1)
Romeo_Julieta
# Out:
#                   title  year
# 53879  Romeo and Juliet  1916

# %% [markdown]
# * Listar todas las peliculas que contengan la palabra ``Exorcist`` ordenadas de la más antigua a la más reciente.

# %%
titulo_sin_NaN=titulos.fillna("0")
#rellena con cadena "0" los NaN

# %%
#str.contains daba error al comparar valores NaN.

exorcista=titulo_sin_NaN[titulo_sin_NaN.title.str.contains("Exorcist")].sort_values("year").set_index("title")
exorcista
# Out:
#                                         year
# title
# The Exorcist                            1973
# O Exorcista de Mulheres                 1974
# Exorcist II: The Heretic                1977
# Kung Fu Exorcist                        1978
# The Exorcist III                        1990
# Teenage Exorcist                        1991
# Exorcist: The Beginning                 2004
# Dominion: Prequel to the Exorcist       2005
# Costa Chica: Confession of an Exorcist  2006
# Exorcist Chronicles                     2007
# The Disco Exorcist                      2011
# Exorcist Chronicles                     2013
# Shark Exorcist                          2015
# Bad Exorcists                           2015
# Exorcistas                              2015
# Accidental Exorcist                     2016
# American Exorcist                       2016
# Diary of an Exorcist                    2016
# Exorcist House of Evil                  2016

# %% [markdown]
# * ¿Cuántas peliculas fueron hechas en el año 1950?

# %%
peliculas_1950=titulos[titulos.year==1950].shape[0]
peliculas_1950
# Out:
# 1081

# %% [markdown]
# * ¿Cuántas peliculas fueron hechas en el año 1970?

# %%
peliculas_1970=titulos[titulos.year==1970].shape[0]
peliculas_1970
# Out:
# 2106

# %% [markdown]
# * ¿Cuántas peliculas fueron hechas de 1950 a 1959.

# %%
peliculas_1950_1970=titulos[(titulos.year>=1950)&(titulos.year<=1959)]
peliculas_1950_1970.shape[0]
# Out:
# 12606

# %% [markdown]
# * ¿En qué años alguna pelicula llamada ``Batman`` se estrenó?

# %%
batman=titulos[titulos.title=="Batman"].set_index("title")
batman
# Out:
#         year
# title
# Batman  1989
# Batman  1943

# %% [markdown]
# * ¿Cuántos roles o papeles hubo en la pelicula ``The Godfather``?

# %%
godfather=cast[["name", "type","character"]][cast.title=="The Godfather"].set_index("type").sort_values("name")
godfather
# Out:
#                    name                character
# type
# actor        Abe Vigoda                   Tessio
# actor       Al Lettieri                 Sollozzo
# actor        Al Martino           Johnny Fontane
# actor         Al Pacino         Michael Corleone
# actor        Alex Rocco               Moe Greene
# ...                 ...                      ...
# actor         Tony King        Tony - Stablehand
# actor          Tony Lip            Wedding Guest
# actress   Tybee Brascia  Dancer in Wedding Scene
# actor    Victor Rendina         Philip Tattaglia
# actor       Vito Scotti                 Nazorine
#
# [76 rows x 2 columns]

# %%
godfather.shape[0]
# Out:
# 76

# %% [markdown]
# * ¿Cuántos papeles en la pelicula ``The Godfather`` no estan clasificados en algun valor ``n``?

# %%
# the godfather sin NaN
godfather_dropna=cast[cast.title=="The Godfather"].dropna().shape[0]
#todos los actores de Godfather - actores con valor n
godfather.shape[0]-godfather_dropna
# Out:
# 42

# %% [markdown]
# * ¿Cuántos papeles en la pelicula ``The Godfather`` si estuvieron clasificados con un valor ``n``?

# %%
# actores con valor n
godfather_dropna
# Out:
# 34

# %% [markdown]
# * Mostrar el elenco completo de la pelicula ``2001: A Space Odyssey``  ordenado por su clasificasión ``n``, ignorando los papeles que no se les asigno ningun valor ``n``.

# %%
space=cast[["name", "character", "n"]][(cast.title=="2001: A Space Odyssey")].dropna().sort_values("n")
space
# Out:
#                      name                       character     n
# 2795          Keir Dullea                 Dr. Dave Bowman   1.0
# 88927       Gary Lockwood                 Dr. Frank Poole   2.0
# 13186   William Sylvester            Dr. Heywood R. Floyd   3.0
# 23947      Daniel Richter                    Moon-Watcher   4.0
# 72093    Leonard Rossiter              Dr. Andrei Smyslov   5.0
# 64754     Margaret Tyzack                           Elena   6.0
# 51781       Robert Beatty             Dr. Ralph Halvorsen   7.0
# 1643        Sean Sullivan               Dr. Bill Michaels   8.0
# 75057        Douglas Rain                        HAL 9000   9.0
# 69910        Frank Miller              Mission Controller  10.0
# 10523         Bill Weston                       Astronaut  11.0
# 97975           Ed Bishop  Aries-1B Lunar Shuttle Captain  12.0
# 53470          Glenn Beck                       Astronaut  13.0
# 88106        Alan Gifford                  Poole's Father  14.0
# 87922          Ann Gillis                  Poole's Mother  15.0
# 72025      Edwina Carroll             Aries-1B Stewardess  16.0
# 29579        Penny Brahms                      Stewardess  17.0
# 90543     Heather Downham                      Stewardess  18.0
# 2983          Mike Lovell                       Astronaut  19.0
# 85047   John (III) Ashley                             Ape  20.0
# 61571          Jimmy Bell                             Ape  21.0
# 73027      David Charkham                             Ape  22.0
# 14378         Simon Davis                             Ape  23.0
# 15635        Jonathan Daw                             Ape  24.0
# 41763        P?ter Delm?r                             Ape  25.0
# 1760         Terry Duggan         Ape Attacked by Leopard  26.0
# 2077      David Fleetwood                             Ape  27.0
# 49029        Danny Grover                             Ape  28.0
# 16925        Brian Hawley                             Ape  29.0
# 54413         David Hines                             Ape  30.0
# 30910        Tony Jackson                             Ape  31.0
# 74233     John (X) Jordan                             Ape  32.0
# 29956        Scott MacKee                             Ape  33.0
# 61809   Laurence Marchant                             Ape  34.0
# 44362         Darryl Paes                             Ape  35.0
# 1551           Joe Refalo                             Ape  36.0
# 73687        Andy Wallace                             Ape  37.0
# 43583         Bob Wilyman                             Ape  38.0
# 59428  Richard (II) Woods      Ape Killed by Moon-Watcher  39.0

# %% [markdown]
# * Mostrar el elenco completo ordenado por la clasificacion ``n`` de la pelicula ``Dracula`` de 1958

# %%
Dracula_n=cast[(cast.title=="Dracula")&(cast.year==1958)].sort_values("n")
Dracula_n
# Out:
#        Unnamed: 0    title  year                   name     type
# 85197      485197  Dracula  1958          Peter Cushing    actor  \
# 42307     1242307  Dracula  1958        Christopher Lee    actor
# 42308     1242308  Dracula  1958        Christopher Lee    actor
# 22398      822398  Dracula  1958          Michael Gough    actor
# 10427     3410427  Dracula  1958      Melissa Stribling  actress
# 69196     3069196  Dracula  1958            Carol Marsh  actress
# 77557     2677557  Dracula  1958            Olga Dickie  actress
# 20986     2220986  Dracula  1958        John Van Eyssen    actor
# 77216     2777216  Dracula  1958          Valerie Gaunt  actress
# 31182     2731182  Dracula  1958            Janina Faye  actress
# 44220     2444220  Dracula  1958         Barbara Archer  actress
# 85506     1285506  Dracula  1958     Charles Lloyd Pack    actor
# 53367     1453367  Dracula  1958         George Merritt    actor
# 57769     2357769  Dracula  1958      George Woodbridge    actor
# 71732      171732  Dracula  1958          George Benson    actor
# 47640     1347640  Dracula  1958         Miles Malleson    actor
# 48496      148496  Dracula  1958       Geoffrey Bayldon    actor
# 23307      423307  Dracula  1958              Paul Cole    actor
# 75047     1475047  Dracula  1958              Guy Mills    actor
# 13434     1513434  Dracula  1958  Richard (VIII) Morgan    actor
# 24497     1524497  Dracula  1958      John (II) Mossman    actor
#
#                       character     n
# 85197        Doctor Van Helsing   1.0
# 42307                   Dracula   2.0
# 42308             Count Dracula   2.0
# 22398                    Arthur   3.0
# 10427                      Mina   4.0
# 69196                      Lucy   5.0
# 77557                     Gerda   6.0
# 20986                  Jonathan   7.0
# 77216             Vampire Woman   8.0
# 31182                     Tania   9.0
# 44220                      Inga  10.0
# 85506             Doctor Seward  11.0
# 53367                 Policeman  12.0
# 57769                  Landlord  13.0
# 71732                  Official  14.0
# 47640                Undertaker  15.0
# 48496                    Porter  16.0
# 23307                       Lad  17.0
# 75047              Coach Driver   NaN
# 13434  Coach Driver's Companion   NaN
# 24497             Hearse Driver   NaN

# %% [markdown]
# * ¿Cuantos papeles fueron listados en la pelicula ``The Wizard of Oz`` de 1939?

# %%
Oz=cast[(cast.title=="The Wizard of Oz")&(cast.year==1939)]
Oz.shape[0]
# Out:
# 128

# %% [markdown]
# * ¿Cuántos papeles de ``Bruce Wayne`` han sido hechos en la historia de las peliculas?

# %%
bruce=cast[cast.character=="Bruce Wayne"]
bruce.shape[0]
# Out:
# 38

# %% [markdown]
# * ¿Cuánta gente ha hecho el papel de ``Romeo``?

# %%
romeo=cast[cast.character=="Romeo"]
romeo.shape[0]
# Out:
# 219

# %% [markdown]
# * ¿Cuántos papeles ha hecho ``Robert De Niro`` en su carrera?

# %%
robert_de_niro=cast[cast.name=="Robert De Niro"]
robert_de_niro.shape[0]
# Out:
# 103

# %% [markdown]
# * Listado de papeles de soporte que tuvo el actor ``Charlton Heston`` en la decada de los 50's, ordenado por año.

# %%
#Todos los papeles de Charlton Heston
charlton_heston=cast[(cast.name=="Charlton Heston")&(cast.year>=1950)&(cast.year<1960)].sort_values("year")
charlton_heston
# Out:
#        Unnamed: 0                            title  year             name
# 44051      944051                        Dark City  1950  Charlton Heston  \
# 44064      944064                    Julius Caesar  1950  Charlton Heston
# 44107      944107                       The Savage  1952  Charlton Heston
# 44093      944093       The Greatest Show on Earth  1952  Charlton Heston
# 44108      944108                       The Savage  1952  Charlton Heston
# 44080      944080                      Ruby Gentry  1952  Charlton Heston
# 44104      944104             The President's Lady  1953  Charlton Heston
# 44045      944045                        Arrowhead  1953  Charlton Heston
# 44046      944046               Bad for Each Other  1953  Charlton Heston
# 44079      944079                     Pony Express  1953  Charlton Heston
# 44098      944098                 The Naked Jungle  1954  Charlton Heston
# 44081      944081              Secret of the Incas  1954  Charlton Heston
# 44106      944106  The Private War of Major Benson  1955  Charlton Heston
# 44067      944067                     Lucy Gallant  1955  Charlton Heston
# 44091      944091                 The Far Horizons  1955  Charlton Heston
# 44113      944113             Three Violent People  1956  Charlton Heston
# 44109      944109             The Ten Commandments  1956  Charlton Heston
# 44088      944088                    The Buccaneer  1958  Charlton Heston
# 44087      944087                  The Big Country  1958  Charlton Heston
# 44115      944115                    Touch of Evil  1958  Charlton Heston
# 44047      944047                          Ben-Hur  1959  Charlton Heston
# 44112      944112      The Wreck of the Mary Deare  1959  Charlton Heston
#
#         type                        character    n
# 44051  actor                      Danny Haley  1.0
# 44064  actor                           Antony  2.0
# 44107  actor           James 'Jim' Aherne Jr.  1.0
# 44093  actor                      Brad Braden  3.0
# 44108  actor                       War Bonnet  1.0
# 44080  actor                    Boake Tackman  2.0
# 44104  actor         President Andrew Jackson  2.0
# 44045  actor                        Ed Bannon  1.0
# 44046  actor                     Dr. Tom Owen  1.0
# 44079  actor                Buffalo Bill Cody  1.0
# 44098  actor            Christopher Leiningen  2.0
# 44081  actor                     Harry Steele  1.0
# 44106  actor  Maj. Bernard R. 'Barney' Benson  1.0
# 44067  actor                       Casey Cole  2.0
# 44091  actor                Lt. William Clark  2.0
# 44113  actor              Capt. Colt Saunders  1.0
# 44109  actor                            Moses  1.0
# 44088  actor              Gen. Andrew Jackson  7.0
# 44087  actor                      Steve Leech  4.0
# 44115  actor                      Mike Vargas  1.0
# 44047  actor                    Judah Ben-Hur  1.0
# 44112  actor                       John Sands  2.0

# %%
charlton_heston_secundario=cast[(cast.name=="Charlton Heston")&(cast.year>=1950)&(cast.year<1960)&(cast.n!=1.0)]

# %%
charlton_heston_secundario.reset_index()
# Out:
#    index  Unnamed: 0                        title  year             name
# 0  44064      944064                Julius Caesar  1950  Charlton Heston  \
# 1  44067      944067                 Lucy Gallant  1955  Charlton Heston
# 2  44080      944080                  Ruby Gentry  1952  Charlton Heston
# 3  44087      944087              The Big Country  1958  Charlton Heston
# 4  44088      944088                The Buccaneer  1958  Charlton Heston
# 5  44091      944091             The Far Horizons  1955  Charlton Heston
# 6  44093      944093   The Greatest Show on Earth  1952  Charlton Heston
# 7  44098      944098             The Naked Jungle  1954  Charlton Heston
# 8  44104      944104         The President's Lady  1953  Charlton Heston
# 9  44112      944112  The Wreck of the Mary Deare  1959  Charlton Heston
#
#     type                 character    n
# 0  actor                    Antony  2.0
# 1  actor                Casey Cole  2.0
# 2  actor             Boake Tackman  2.0
# 3  actor               Steve Leech  4.0
# 4  actor       Gen. Andrew Jackson  7.0
# 5  actor         Lt. William Clark  2.0
# 6  actor               Brad Braden  3.0
# 7  actor     Christopher Leiningen  2.0
# 8  actor  President Andrew Jackson  2.0
# 9  actor                John Sands  2.0

# %% [markdown]
# * Listado de papeles como protagonista que tuvo el actor ``Charlton Heston`` en la decada de los 60's, ordenado por año de forma descendente.

# %%
#Todos los principales
charlton_heston_principal=cast[(cast.name=="Charlton Heston")&(cast.year>=1950)&(cast.year<1960)&(cast.n==1.0)].sort_values("year", ascending=False).reset_index()
charlton_heston_principal
# Out:
#     index  Unnamed: 0                            title  year             name
# 0   44047      944047                          Ben-Hur  1959  Charlton Heston  \
# 1   44115      944115                    Touch of Evil  1958  Charlton Heston
# 2   44109      944109             The Ten Commandments  1956  Charlton Heston
# 3   44113      944113             Three Violent People  1956  Charlton Heston
# 4   44106      944106  The Private War of Major Benson  1955  Charlton Heston
# 5   44081      944081              Secret of the Incas  1954  Charlton Heston
# 6   44045      944045                        Arrowhead  1953  Charlton Heston
# 7   44046      944046               Bad for Each Other  1953  Charlton Heston
# 8   44079      944079                     Pony Express  1953  Charlton Heston
# 9   44107      944107                       The Savage  1952  Charlton Heston
# 10  44108      944108                       The Savage  1952  Charlton Heston
# 11  44051      944051                        Dark City  1950  Charlton Heston
#
#      type                        character    n
# 0   actor                    Judah Ben-Hur  1.0
# 1   actor                      Mike Vargas  1.0
# 2   actor                            Moses  1.0
# 3   actor              Capt. Colt Saunders  1.0
# 4   actor  Maj. Bernard R. 'Barney' Benson  1.0
# 5   actor                     Harry Steele  1.0
# 6   actor                        Ed Bannon  1.0
# 7   actor                     Dr. Tom Owen  1.0
# 8   actor                Buffalo Bill Cody  1.0
# 9   actor           James 'Jim' Aherne Jr.  1.0
# 10  actor                       War Bonnet  1.0
# 11  actor                      Danny Haley  1.0

# %% [markdown]
# * ¿Cuántos papeles para actores hubo en la decada de los 50's?

# %%
actores_50s=cast[(cast.type=="actor")&(cast.year>=1950)&(cast.year<1960)]
actores_50s.shape[0]
# Out:
# 153998

# %% [markdown]
# * ¿Cuántos papeles para actrices hubo en la decada de los 50's ?

# %%
actrices_50s=cast[(cast.type=="actress")&(cast.year>=1950)&(cast.year<1960)]
actrices_50s.shape[0]
# Out:
# 56004

# %% [markdown]
# * ¿Cuantos papeles protagonistas existen desde el principio de la historia filmatografica hasta 1970 ?

# %%
papeles_1970=cast[(cast.year<1970)&(cast.n==1)]
papeles_1970.shape[0]
# Out:
# 50189

# %% [markdown]
# ## Ejercicio 2

# %% [markdown]
# * Graficar la diferencia entre el numero de papeles  para actores cada año y el numero de papeles para actrices cada año en la historia de la filmografia.

# %%
import matplotlib.pyplot as plt

plt.plot(actores_50s[["year"]])

# %% [markdown]
# ## Ejercicio 2
#
# * Graficar en numero de papeles de actores cada año y el numero de papeles para actrices cada año.
# * El mismo grafico anterior pero categorizado por decada y con un grafico de area.
# * Graficar el porcentaje de papeles que han sido actores cada año en la historia de la filmografia
# * Graficar el porcentaje de papeles que han sido  actores cada año en la historia de la filmografia junto al mismo porcentaje pero de actrices
# * Graficar 3 lines con clasificacion "n" de 1 al 3 donde cada  linea represente el porcentaje de la clasificacion para  los papeles de actores en cada año.
# * Encontrar las 5 peliculas de la historia tengan más actrices que actores

# %% [markdown]
# ## Ejercicio 3

# %% [markdown]
# * En que fechas fue lanzada cada pelicula de ``Salma Hayek`` desde  1990 al presente en Mexico

# %%
peliculas_mexicanas=estreno[["title", "date"]][(estreno.country=="Mexico")&(estreno.year>1990)]
peliculas_mexicanas

salma=cast[cast.name=="Salma Hayek"]

salma.reset_index(drop=True)
#  merge peliculas_mexicanas y salma
# Out:
#     Unnamed: 0                                          title  year
# 0      2847362                                             54  1998  \
# 1      2847363                            Across the Universe  2007
# 2      2847364                               After the Sunset  2004
# 3      2847365                                      Americano  2011
# 4      2847366                                   Ask the Dust  2006
# 5      2847367                                       Bandidas  2006
# 6      2847368                              Beatriz at Dinner  2017
# 7      2847369                                    Breaking Up  1997
# 8      2847370                                 Chain of Fools  2000
# 9      2847371       Cirque du Freak: The Vampire's Assistant  2009
# 10     2847372                                      Desperado  1995
# 11     2847373                                          Dogma  1999
# 12     2847374           El coronel no tiene quien le escriba  1999
# 13     2847375                                         Everly  2014
# 14     2847376                                      Fair Game  1995
# 15     2847377                                           Fled  1996
# 16     2847378                                 Follow Me Home  1996
# 17     2847379                                  Fools Rush In  1997
# 18     2847380                                     Four Rooms  1995
# 19     2847381                                          Frida  2002
# 20     2847382                            From Dusk Till Dawn  1996
# 21     2847383                                      Grown Ups  2010
# 22     2847384                                    Grown Ups 2  2013
# 23     2847385                            Here Comes the Boom  2012
# 24     2847386                                          Hotel  2001
# 25     2847387            How to Make Love Like an Englishman  2014
# 26     2847388       Il racconto dei racconti - Tale of Tales  2015
# 27     2847389                           La chispa de la vida  2011
# 28     2847390                                   La gran vida  2000
# 29     2847391                                  Lonely Hearts  2006
# 30     2847392                                   Mi vida loca  1993
# 31     2847393                            Muppets Most Wanted  2014
# 32     2847394                     Once Upon a Time in Mexico  2003
# 33     2847395                                  Puss in Boots  2011
# 34     2847396                                  Sausage Party  2016
# 35     2847397                                        Savages  2012
# 36     2847398                           Septembers of Shiraz  2015
# 37     2847399                        Spy Kids 3-D: Game Over  2003
# 38     2847400                                    The Faculty  1998
# 39     2847401  The Pirates! In an Adventure with Scientists!  2012
# 40     2847402                                    The Prophet  2014
# 41     2847403     The Velocity of Gary* *(Not His Real Name)  1998
# 42     2847404                                       Timecode  2000
# 43     2847405                                        Traffic  2000
# 44     2847406                           Welcome to Hollywood  1998
# 45     2847407                                 Wild Wild West  1999
#
#            name     type                                    character     n
# 0   Salma Hayek  actress                               Anita Randazzo   2.0
# 1   Salma Hayek  actress                                Singing Nurse  66.0
# 2   Salma Hayek  actress                                 Lola Cirillo   2.0
# 3   Salma Hayek  actress                                       'Lola'   6.0
# 4   Salma Hayek  actress                                      Camilla   2.0
# 5   Salma Hayek  actress                                Sara Sandoval   2.0
# 6   Salma Hayek  actress                                      Beatriz   NaN
# 7   Salma Hayek  actress                                       Monica   2.0
# 8   Salma Hayek  actress                                        Kolko   2.0
# 9   Salma Hayek  actress                                Madame Truska  12.0
# 10  Salma Hayek  actress                                     Carolina   2.0
# 11  Salma Hayek  actress                                  Serendipity  28.0
# 12  Salma Hayek  actress                                        Julia   3.0
# 13  Salma Hayek  actress                                       Everly   1.0
# 14  Salma Hayek  actress                                         Rita   7.0
# 15  Salma Hayek  actress                                         Cora  11.0
# 16  Salma Hayek  actress                                     Veronica   2.0
# 17  Salma Hayek  actress                       Isabel Fuentes Whitman   2.0
# 18  Salma Hayek  actress  TV Dancing Girl (segment "The Misbehavers")  15.0
# 19  Salma Hayek  actress                                  Frida Kahlo   1.0
# 20  Salma Hayek  actress                        Santanico Pandemonium   6.0
# 21  Salma Hayek  actress                          Roxanne Chase-Feder   6.0
# 22  Salma Hayek  actress                          Roxanne Chase-Feder   5.0
# 23  Salma Hayek  actress                                 Bella Flores   2.0
# 24  Salma Hayek  actress                                 Charlee Boux  13.0
# 25  Salma Hayek  actress                                       Olivia   2.0
# 26  Salma Hayek  actress                         Queen of Longtrellis   1.0
# 27  Salma Hayek  actress                                        Luisa   2.0
# 28  Salma Hayek  actress                                         Lola   1.0
# 29  Salma Hayek  actress                                  Martha Beck   4.0
# 30  Salma Hayek  actress                                         Gata  24.0
# 31  Salma Hayek  actress                                      Herself  24.0
# 32  Salma Hayek  actress                                     Carolina   2.0
# 33  Salma Hayek  actress                               Kitty Softpaws   2.0
# 34  Salma Hayek  actress                                       Teresa  12.0
# 35  Salma Hayek  actress                                        Elena  17.0
# 36  Salma Hayek  actress                                       Farnez   NaN
# 37  Salma Hayek  actress                                Cesca Giggles   9.0
# 38  Salma Hayek  actress                            Nurse Rosa Harper   6.0
# 39  Salma Hayek  actress                                  Cutlass Liz   6.0
# 40  Salma Hayek  actress                                       Kamila   NaN
# 41  Salma Hayek  actress                                  Mary Carmen   2.0
# 42  Salma Hayek  actress                                         Rose   7.0
# 43  Salma Hayek  actress                                      Rosario   NaN
# 44  Salma Hayek  actress                                      Herself   NaN
# 45  Salma Hayek  actress                                 Rita Escobar   4.0

# %%
salma_mexico=pd.merge(peliculas_mexicanas,salma, left_on="title", right_on="title", how="inner")[["title","date"]].set_index("title")

# %%
salma_mexico
# Out:
#                                                      date
# title
# Across the Universe                            2007-11-16
# After the Sunset                               2005-01-14
# Americano                                      2012-12-07
# Ask the Dust                                   2006-11-17
# Bandidas                                       2006-02-17
# Cirque du Freak: The Vampire's Assistant       2009-10-30
# El coronel no tiene quien le escriba           1999-09-16
# Fair Game                                      2011-03-25
# Fools Rush In                                  1997-05-16
# Four Rooms                                     1996-11-13
# Frida                                          2002-11-20
# From Dusk Till Dawn                            1996-06-14
# Grown Ups                                      2010-07-23
# Grown Ups 2                                    2013-08-16
# Here Comes the Boom                            2012-12-28
# Hotel                                          2008-05-29
# How to Make Love Like an Englishman            2015-09-03
# La chispa de la vida                           2012-11-02
# La gran vida                                   2001-06-01
# Lonely Hearts                                  2007-07-20
# Once Upon a Time in Mexico                     2003-10-24
# Puss in Boots                                  2011-10-28
# Sausage Party                                  2016-10-30
# Savages                                        2012-07-13
# Spy Kids 3-D: Game Over                        2003-10-10
# The Pirates! In an Adventure with Scientists!  2012-04-20
# The Prophet                                    2016-01-22
# Traffic                                        2001-03-19

# %%
salma_mexico[["title","date"]].set_index("title")
# Out:
#                                                      date
# title
# Across the Universe                            2007-11-16
# After the Sunset                               2005-01-14
# Americano                                      2012-12-07
# Ask the Dust                                   2006-11-17
# Bandidas                                       2006-02-17
# Cirque du Freak: The Vampire's Assistant       2009-10-30
# El coronel no tiene quien le escriba           1999-09-16
# Fair Game                                      2011-03-25
# Fools Rush In                                  1997-05-16
# Four Rooms                                     1996-11-13
# Frida                                          2002-11-20
# From Dusk Till Dawn                            1996-06-14
# Grown Ups                                      2010-07-23
# Grown Ups 2                                    2013-08-16
# Here Comes the Boom                            2012-12-28
# Hotel                                          2008-05-29
# How to Make Love Like an Englishman            2015-09-03
# La chispa de la vida                           2012-11-02
# La gran vida                                   2001-06-01
# Lonely Hearts                                  2007-07-20
# Once Upon a Time in Mexico                     2003-10-24
# Puss in Boots                                  2011-10-28
# Sausage Party                                  2016-10-30
# Savages                                        2012-07-13
# Spy Kids 3-D: Game Over                        2003-10-10
# The Pirates! In an Adventure with Scientists!  2012-04-20
# The Prophet                                    2016-01-22
# Traffic                                        2001-03-19

# %% [markdown]
# * En que dia de la semana se han lanzado en USA las peliculas donde aparece ``Tom Cuise``. Incluir un grafico

# %% [markdown]
# * ¿Que peliculas han sido lanzadas en la mayor cantidad de paises?, incluir en un grafico las 5 mayores.
# * ¿Quien tiende a ser el actor si clasificado (n > 1) que mas a  participado en peliculas donde el protagonista es ``Leonardo DiCaprio``?
